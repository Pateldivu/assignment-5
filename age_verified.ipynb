# %%
age = 18
number = input('enter your age to check age for licence: ')

if number.isnumeric():
  number = int(number)

  if number >= age:
    print('your age is verified for lincense')
  else:
    print('your age is not verified for lincense')

    if number <=17:
      a = age - number
      print(f'{a} years are left for your verification')
else:
  print('invalid input')
# Out:
# enter your age to check age for licence: 12
# your age is not verified for lincense
# 6 years are left for your verification

# %%
dict = {'A' : [1, 3, 5, 4],'B' : [4, 6, 3, 10]}
        
  
res = list(sorted({ele for val in dict.values() for ele in val}))
   
print("The unique values list is : " , res)
# Out:
# The unique values list is :  [1, 3, 4, 5, 6, 10]

# %%
dict = {'A' : [1, 3, 5, 4],'B' : [4, 6, 3, 10]}
        

print("The original dictionary is : " ,dict)
  
res = list(sorted({ele for val in dict.values() for ele in val}))
   
print("The unique values list is : " , res)
# Out:
# The original dictionary is :  {'A': [1, 3, 5, 4], 'B': [4, 6, 3, 10]}
# The unique values list is :  [1, 3, 4, 5, 6, 10]
